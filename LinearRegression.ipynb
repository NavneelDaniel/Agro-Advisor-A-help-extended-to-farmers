# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.linear_model import LinearRegression

# %%
data = pd.read_csv('C:/Users/lenovo/Desktop/Agro/Book4.csv')
data
plt.plot(data.Year,data.Paddy)
print(data)
# Out:
#    Year   MSP    GDP  Paddy  Jowar   Tur  Maize  Groundnut  Arhar  Gram  \
# 0  2010   880  1.660   1030    900  3000    880       2300   3000  2100
# 1  2011   980  1.820   1110   1000  3200    980       2700   3200  2800
# 2  2012  1175  1.830   1280   1520  3850   1175       3700   3850  3000
# 3  2013  1250  1.860   1345   1520  4300   1310       4000   4300  3100
# 4  2014  1250  2.040   1400   1550  4350   1310       4000   4350  3175
# 5  2015  1275  2.100   1450   1590  4625   1325       4030   4625  3500
# 6  2016  1330  2.270   1510   1650  5050   1365       4220   5050  4000
# 7  2017  1425  2.600   1590   1725  5450   1425       4450   5450  4400
# 8  2018  1950  2.718   1770   2450  5675   1700       4890   5675  4620
# 9  2019  1600  2.972   1835   2570  5800   1760       5090   5800  4875
#
#    Mustard  Cotton  Sunflower  Soyabean  Wheat  Barley  Sugarcane  Safflower
# 0     1850    3000       2350      1400   1120     780     139.12       1800
# ...

# %%
# X = data.iloc[:, 0].values.reshape(-1, 1)
# Y = data.iloc[:, 1].values.reshape(-1, 1)
# lr = LinearRegression()
# lr.fit(X,Y)
# Y_pred=lr.predict(X)
# X=data['Year'].values
# Y=data['MSP'].values
# X=data.Year
# Y=data.MSP
# X1=X.values
# X2=np.reshape(X1,(-1,1))
# print(X2)
# Y1=Y.values
# Y2=np.reshape(Y1,(-1,1))
# print(Y2)
# X=data['Year'].values.reshape(-1,1)
# Y=data['MSP'].values.reshape(-1,1)
X=data['Year'].values.reshape(-1,1)
Y=data['GDP'].values.reshape(-1,1)

# %%
# reg=LinearRegression()
# reg.fit(X2,Y2)

# plt.scatter(X,Y)
reg=LinearRegression()
reg.fit(X,Y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
plt.scatter(X,Y,color='blue')
plt.plot(X,reg.predict(X),color='red',linewidth=3)
plt.show()

# %%
multi=reg.predict(X)
result1=reg.predict([[2020]])
print(result1)
# Out:
# [[2.96146667]]

# %%
X=data['Year'].values.reshape(-1,1)
Z=data['Safflower'].values.reshape(-1,1)

# %%
reg1=LinearRegression()
reg1.fit(multi,Z)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
plt.scatter(multi,Z,color='blue')
plt.plot(multi,reg1.predict(multi),color='red',linewidth=3)
plt.show()

# %%
result2=reg1.predict(result1)

# %%
print("The MSP of year 2020 estimates to be",float(result2))
# print(result2)
# Out:
# The MSP of year 2020 estimates to be 5330.999999999955
